# %% [markdown]
# Q1 Write a program to print the 4th element from first and 4th element from last in a tuple.

# %%
tup = (1, 2, 30, 40, 55, 60, 7, 80)

print("4th element from first:", tup[3])
print("4th element from last:", tup[-4])
# Out:
# 4th element from first: 40
# 4th element from last: 55

# %% [markdown]
# Q2 Write a program to check whether an element exists in a tuple or not.

# %%
tup = (10, 20, 30, 40, 50)

element = int(input("Enter the element: "))

if element in tup:
    print("Element exists in the tuple.")
else:
    print("Element does not exist in the tuple.")
# Out:
# Element exists in the tuple.

# %% [markdown]
# Q3 Write a program to convert a list into a tuple.

# %%
list = [10, 20, 30, 40, 50 , 20 ,30]

tup = tuple(list)

print("Tuple:", tup)
# Out:
# Tuple: (10, 20, 30, 40, 50, 20, 30)

# %% [markdown]
# Q4 Write a program to find the index of an item in a tuple.

# %%
tup = (10, 20, 30, 40, 50)

element = int(input("Enter the element"))

if element in tup:
    print("Index:", tup.index(element))
else:
    print("Element not found.")
# Out:
# Index: 1

# %% [markdown]
# Q5 Write a program to replace last value of tuples in a list to 100.
# Sample list: [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
# Expected Output: [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
list = [(10, 20, 40), (40, 50, 60), (70, 80, 90)]

new_list = []

for tup in list:
    new_tuple = tup[:-1] + (100,)
    new_list.append(new_tuple)

print(new_list)
# Out:
# [(10, 20, 100), (40, 50, 100), (70, 80, 100)]
